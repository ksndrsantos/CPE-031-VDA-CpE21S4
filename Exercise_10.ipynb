# %% [markdown]
# <a href="https://colab.research.google.com/github/ksndrsantos/CpE-031-VDA-CpE21s4/blob/main/Exercise_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import numpy as np
import matplotlib.pyplot as plt

#generate data
x = np.array([1,2,3,4,5])
y = np.array([2,4,5,4,5])

#calculate the slope and y-intercept of the regression line
slope, intercept = np.polyfit(x,y,1)

#calculate the predicted values of y using regression line equation
y_pred = slope*x+ intercept

#plot the original data points and the regression line
plt.scatter(x,y)
plt.plot(x,y_pred, color = 'red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2,2,100)
y= x**2

fig = plt.figure(figsize=(10,5))
plt.plot (x,y)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
